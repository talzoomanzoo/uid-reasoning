# %%
#quant push to hub
from huggingface_hub import create_repo, upload_folder

repo_id = "talzoomanzoo/DeepSeek-R1-Distill-Qwen-7B-awq"
local_model_path = "/home/mjgwak/workspace/search-o1-dev/src/mj_test/DeepSeek-R1-Distill-Qwen-7B-awq"

create_repo(repo_id, exist_ok=True, private=False)

upload_folder(
    repo_id=repo_id,
    folder_path=local_model_path,
    repo_type="model",
    commit_message="DeepSeek-R1-Distill-Qwen-7B-awq"
)

# %%
#quant sft-on-gt lora push to hub
from huggingface_hub import create_repo, upload_folder

repo_id = "talzoomanzoo/DeepSeek-R1-Distill-Qwen-7B-awq-sft-on-gt-lora"
local_model_path = "/home/mjgwak/workspace/search-o1-dev/OpenRLHF/mj_scripts/checkpoint/deepseek-7b-sft-gt-lora-awq"

create_repo(repo_id, exist_ok=True, private=False)

upload_folder(
    repo_id=repo_id,
    folder_path=local_model_path,
    repo_type="model",
    commit_message="DeepSeek-R1-Distill-Qwen-7B-awq-sft-gt-lora"
)
# Out:
# 100%|██████████| 2/2 [00:16<00:00,  8.24s/it]
# CommitInfo(commit_url='https://huggingface.co/talzoomanzoo/DeepSeek-R1-Distill-Qwen-7B-awq-sft-on-gt-lora/commit/dc04b2c5db4c3a173b4997ad40b0beb598851d52', commit_message='DeepSeek-R1-Distill-Qwen-7B-awq-sft-gt-lora', commit_description='', oid='dc04b2c5db4c3a173b4997ad40b0beb598851d52', pr_url=None, repo_url=RepoUrl('https://huggingface.co/talzoomanzoo/DeepSeek-R1-Distill-Qwen-7B-awq-sft-on-gt-lora', endpoint='https://huggingface.co', repo_type='model', repo_id='talzoomanzoo/DeepSeek-R1-Distill-Qwen-7B-awq-sft-on-gt-lora'), pr_revision=None, pr_num=None)

# %%
#quant sft-on-gt-lora-merged push to hub
from huggingface_hub import create_repo, upload_folder

repo_id = "talzoomanzoo/DeepSeek-R1-Distill-Qwen-7B-awq-sft-on-gt-lora-merged"
local_model_path = "/home/mjgwak/workspace/search-o1-dev/models/0514-deepseek-7b-awq-sft-gt-lora-merged"

create_repo(repo_id, exist_ok=True, private=False)

upload_folder(
    repo_id=repo_id,
    folder_path=local_model_path,
    repo_type="model",
    commit_message="DeepSeek-R1-Distill-Qwen-7B-awq-sft-gt-lora-merged"
)

# %%
#quant rft-on-y-lora-y-true-awq push to hub
from huggingface_hub import create_repo, upload_folder

repo_id = "talzoomanzoo/DeepSeek-R1-Distill-Qwen-7B-awq-rft-on-y-lora"
local_model_path = "/home/mjgwak/workspace/search-o1-dev/OpenRLHF/mj_scripts/checkpoint/deepseek-7b-rft-y-lora-y-true-awq"

create_repo(repo_id, exist_ok=True, private=False)

upload_folder(
    repo_id=repo_id,
    folder_path=local_model_path,
    repo_type="model",
    commit_message="DeepSeek-R1-Distill-Qwen-7B-awq-rft-y-lora-y-true"
)
# Out:
# 100%|██████████| 2/2 [00:16<00:00,  8.31s/it]
# CommitInfo(commit_url='https://huggingface.co/talzoomanzoo/DeepSeek-R1-Distill-Qwen-7B-awq-rft-on-y-lora/commit/494eb42a470e1ac8bc6e37bcc31ef9e32d8a835f', commit_message='DeepSeek-R1-Distill-Qwen-7B-awq-rft-y-lora-y-true', commit_description='', oid='494eb42a470e1ac8bc6e37bcc31ef9e32d8a835f', pr_url=None, repo_url=RepoUrl('https://huggingface.co/talzoomanzoo/DeepSeek-R1-Distill-Qwen-7B-awq-rft-on-y-lora', endpoint='https://huggingface.co', repo_type='model', repo_id='talzoomanzoo/DeepSeek-R1-Distill-Qwen-7B-awq-rft-on-y-lora'), pr_revision=None, pr_num=None)
