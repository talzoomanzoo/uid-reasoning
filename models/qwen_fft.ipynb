# %% [markdown]
# ### variance

# %%
from huggingface_hub import create_repo, upload_folder

repo_id = "talzoomanzoo/qwen3-1.7b-highest-uid-variance-fft"
local_model_path = "/workspace/uid-reasoning/OpenRLHF/mj_scripts/checkpoint/qwen3-1.7b-highest-uid-variance-fft"

create_repo(repo_id, exist_ok=True)

upload_folder(
    repo_id=repo_id,
    folder_path=local_model_path,
    repo_type="model",
    commit_message="qwen3-1.7b-highest-uid-variance-fft"
)
# Out:
# Upload 2 LFS files:   0%|          | 0/2 [00:00<?, ?it/s]
# model.safetensors:   0%|          | 0.00/4.06G [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/talzoomanzoo/qwen3-1.7b-highest-uid-variance-fft/commit/70303f6f04519efab29d6844cf02c215a01ac59a', commit_message='qwen3-1.7b-highest-uid-variance-fft', commit_description='', oid='70303f6f04519efab29d6844cf02c215a01ac59a', pr_url=None, repo_url=RepoUrl('https://huggingface.co/talzoomanzoo/qwen3-1.7b-highest-uid-variance-fft', endpoint='https://huggingface.co', repo_type='model', repo_id='talzoomanzoo/qwen3-1.7b-highest-uid-variance-fft'), pr_revision=None, pr_num=None)

# %%
from huggingface_hub import create_repo, upload_folder

repo_id = "talzoomanzoo/qwen3-1.7b-lowest-uid-variance-fft"
local_model_path = "/workspace/uid-reasoning/OpenRLHF/mj_scripts/checkpoint/qwen3-1.7b-lowest-uid-variance-fft"

create_repo(repo_id, exist_ok=True)

upload_folder(
    repo_id=repo_id,
    folder_path=local_model_path,
    repo_type="model",
    commit_message="deepseek-1.5b-lowest-uid-variance-fft"
)
# Out:
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/4.06G [00:00<?, ?B/s]
# Upload 2 LFS files:   0%|          | 0/2 [00:00<?, ?it/s]
# CommitInfo(commit_url='https://huggingface.co/talzoomanzoo/qwen3-1.7b-lowest-uid-variance-fft/commit/590bd7d68cf9e83069c752bec0dad316f14c3214', commit_message='deepseek-1.5b-lowest-uid-variance-fft', commit_description='', oid='590bd7d68cf9e83069c752bec0dad316f14c3214', pr_url=None, repo_url=RepoUrl('https://huggingface.co/talzoomanzoo/qwen3-1.7b-lowest-uid-variance-fft', endpoint='https://huggingface.co', repo_type='model', repo_id='talzoomanzoo/qwen3-1.7b-lowest-uid-variance-fft'), pr_revision=None, pr_num=None)

# %% [markdown]
# ### gini

# %%
from huggingface_hub import create_repo, upload_folder

repo_id = "talzoomanzoo/qwen3-1.7b-highest-uid-gini-fft"
local_model_path = "/workspace/uid-reasoning/OpenRLHF/mj_scripts/checkpoint/qwen3-1.7b-highest-uid-gini-fft"

create_repo(repo_id, exist_ok=True)

upload_folder(
    repo_id=repo_id,
    folder_path=local_model_path,
    repo_type="model",
    commit_message="qwen3-1.7b-highest-uid-gini-fft"
)
# Out:
# model.safetensors:   0%|          | 0.00/4.06G [00:00<?, ?B/s]
# Upload 2 LFS files:   0%|          | 0/2 [00:00<?, ?it/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/talzoomanzoo/qwen3-1.7b-highest-uid-gini-fft/commit/33bae65d78a46d3f07cb7f6d26ea42387c371052', commit_message='qwen3-1.7b-highest-uid-gini-fft', commit_description='', oid='33bae65d78a46d3f07cb7f6d26ea42387c371052', pr_url=None, repo_url=RepoUrl('https://huggingface.co/talzoomanzoo/qwen3-1.7b-highest-uid-gini-fft', endpoint='https://huggingface.co', repo_type='model', repo_id='talzoomanzoo/qwen3-1.7b-highest-uid-gini-fft'), pr_revision=None, pr_num=None)

# %%
from huggingface_hub import create_repo, upload_folder

repo_id = "talzoomanzoo/qwen3-1.7b-lowest-uid-gini-fft"
local_model_path = "/workspace/uid-reasoning/OpenRLHF/mj_scripts/checkpoint/qwen3-1.7b-lowest-uid-gini-fft"

create_repo(repo_id, exist_ok=True)

upload_folder(
    repo_id=repo_id,
    folder_path=local_model_path,
    repo_type="model",
    commit_message="qwen3-1.7b-lowest-uid-gini-fft"
)
# Out:
# model.safetensors:   0%|          | 0.00/4.06G [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# Upload 2 LFS files:   0%|          | 0/2 [00:00<?, ?it/s]
# CommitInfo(commit_url='https://huggingface.co/talzoomanzoo/qwen3-1.7b-lowest-uid-gini-fft/commit/f562d0865c06195d6b7045dc071c72c2cad280db', commit_message='qwen3-1.7b-lowest-uid-gini-fft', commit_description='', oid='f562d0865c06195d6b7045dc071c72c2cad280db', pr_url=None, repo_url=RepoUrl('https://huggingface.co/talzoomanzoo/qwen3-1.7b-lowest-uid-gini-fft', endpoint='https://huggingface.co', repo_type='model', repo_id='talzoomanzoo/qwen3-1.7b-lowest-uid-gini-fft'), pr_revision=None, pr_num=None)

# %% [markdown]
# ### shannon

# %%
from huggingface_hub import create_repo, upload_folder

repo_id = "talzoomanzoo/qwen3-1.7b-highest-uid-shannon-fft"
local_model_path = "/workspace/uid-reasoning/OpenRLHF/mj_scripts/checkpoint/qwen3-1.7b-highest-uid-shannon-fft"

create_repo(repo_id, exist_ok=True)

upload_folder(
    repo_id=repo_id,
    folder_path=local_model_path,
    repo_type="model",
    commit_message="qwen3-1.7b-highest-uid-shannon-fft"
)
# Out:
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/4.06G [00:00<?, ?B/s]
# Upload 2 LFS files:   0%|          | 0/2 [00:00<?, ?it/s]
# CommitInfo(commit_url='https://huggingface.co/talzoomanzoo/qwen3-1.7b-highest-uid-shannon-fft/commit/5a07cf4cf989f544fb2ded0e24c835ac2d4e1cc7', commit_message='qwen3-1.7b-highest-uid-shannon-fft', commit_description='', oid='5a07cf4cf989f544fb2ded0e24c835ac2d4e1cc7', pr_url=None, repo_url=RepoUrl('https://huggingface.co/talzoomanzoo/qwen3-1.7b-highest-uid-shannon-fft', endpoint='https://huggingface.co', repo_type='model', repo_id='talzoomanzoo/qwen3-1.7b-highest-uid-shannon-fft'), pr_revision=None, pr_num=None)

# %%
from huggingface_hub import create_repo, upload_folder

repo_id = "talzoomanzoo/qwen3-1.7b-lowest-uid-shannon-fft"
local_model_path = "/workspace/uid-reasoning/OpenRLHF/mj_scripts/checkpoint/qwen3-1.7b-lowest-uid-shannon-fft"

create_repo(repo_id, exist_ok=True)

upload_folder(
    repo_id=repo_id,
    folder_path=local_model_path,
    repo_type="model",
    commit_message="qwen3-1.7b-lowest-uid-shannon-fft"
)
# Out:
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/4.06G [00:00<?, ?B/s]
# Upload 2 LFS files:   0%|          | 0/2 [00:00<?, ?it/s]
# CommitInfo(commit_url='https://huggingface.co/talzoomanzoo/qwen3-1.7b-lowest-uid-shannon-fft/commit/c1365d69c212dd5bdf3afce9ce883966cac8d1bb', commit_message='qwen3-1.7b-lowest-uid-shannon-fft', commit_description='', oid='c1365d69c212dd5bdf3afce9ce883966cac8d1bb', pr_url=None, repo_url=RepoUrl('https://huggingface.co/talzoomanzoo/qwen3-1.7b-lowest-uid-shannon-fft', endpoint='https://huggingface.co', repo_type='model', repo_id='talzoomanzoo/qwen3-1.7b-lowest-uid-shannon-fft'), pr_revision=None, pr_num=None)
