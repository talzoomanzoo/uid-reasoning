# %%
from huggingface_hub import create_repo, upload_folder

repo_id = "talzoomanzoo/deepseek-1.5b-highest-spikes-falls-ds-1.5b-fft"
local_model_path = "/workspace/uid-reasoning/OpenRLHF/mj_scripts/checkpoint/deepseek-1.5b-highest-spikes-falls-ds-1.5b-fft"

create_repo(repo_id, exist_ok=True)

upload_folder(
    repo_id=repo_id,
    folder_path=local_model_path,
    repo_type="model",
    commit_message="deepseek-1.5b-highest-spikes-falls-ds-1.5b-fft"
)
# Out:
# Processing Files (2 / 2): 100%|██████████| 3.57GB / 3.57GB, 98.4MB/s
# New Data Upload: 100%|██████████| 3.54GB / 3.54GB, 98.4MB/s
# CommitInfo(commit_url='https://huggingface.co/talzoomanzoo/deepseek-1.5b-highest-spikes-falls-ds-1.5b-fft/commit/9bed0d051d0e1073e098195431445f7afbe03c94', commit_message='deepseek-1.5b-highest-spikes-falls-ds-1.5b-fft', commit_description='', oid='9bed0d051d0e1073e098195431445f7afbe03c94', pr_url=None, repo_url=RepoUrl('https://huggingface.co/talzoomanzoo/deepseek-1.5b-highest-spikes-falls-ds-1.5b-fft', endpoint='https://huggingface.co', repo_type='model', repo_id='talzoomanzoo/deepseek-1.5b-highest-spikes-falls-ds-1.5b-fft'), pr_revision=None, pr_num=None)

# %%
from huggingface_hub import create_repo, upload_folder

repo_id = "talzoomanzoo/deepseek-1.5b-highest-uid-variance-ds-1.5b-fft"
local_model_path = "/workspace/uid-reasoning/OpenRLHF/mj_scripts/checkpoint/deepseek-1.5b-highest-uid-variance-ds-1.5b-fft"

create_repo(repo_id, exist_ok=True)

upload_folder(
    repo_id=repo_id,
    folder_path=local_model_path,
    repo_type="model",
    commit_message="deepseek-1.5b-highest-uid-variance-ds-1.5b-fft"
)
# Out:
# Processing Files (2 / 2): 100%|██████████| 3.57GB / 3.57GB, 74.5MB/s
# New Data Upload: 100%|██████████| 3.36GB / 3.36GB, 74.5MB/s
# CommitInfo(commit_url='https://huggingface.co/talzoomanzoo/deepseek-1.5b-highest-uid-variance-ds-1.5b-fft/commit/12bc69fa12245057b8af05674a9cd57b054a744e', commit_message='deepseek-1.5b-highest-uid-variance-ds-1.5b-fft', commit_description='', oid='12bc69fa12245057b8af05674a9cd57b054a744e', pr_url=None, repo_url=RepoUrl('https://huggingface.co/talzoomanzoo/deepseek-1.5b-highest-uid-variance-ds-1.5b-fft', endpoint='https://huggingface.co', repo_type='model', repo_id='talzoomanzoo/deepseek-1.5b-highest-uid-variance-ds-1.5b-fft'), pr_revision=None, pr_num=None)

# %%
from huggingface_hub import create_repo, upload_folder

repo_id = "talzoomanzoo/deepseek-1.5b-lowest-spikes-falls-ds-1.5b-fft"
local_model_path = "/workspace/uid-reasoning/OpenRLHF/mj_scripts/checkpoint/deepseek-1.5b-lowest-spikes-falls-ds-1.5b-fft"

create_repo(repo_id, exist_ok=True)

upload_folder(
    repo_id=repo_id,
    folder_path=local_model_path,
    repo_type="model",
    commit_message="deepseek-1.5b-lowest-spikes-falls-ds-1.5b-fft"
)
# Out:
# Processing Files (1 / 2): 100%|█████████▉| 3.57GB / 3.57GB, 81.0MB/s
# New Data Upload: 100%|██████████| 3.35GB / 3.35GB, 81.0MB/s
# CommitInfo(commit_url='https://huggingface.co/talzoomanzoo/deepseek-1.5b-lowest-spikes-falls-ds-1.5b-fft/commit/116ef5265b99476c877fc7d80e0fec2fad56a773', commit_message='deepseek-1.5b-lowest-spikes-falls-ds-1.5b-fft', commit_description='', oid='116ef5265b99476c877fc7d80e0fec2fad56a773', pr_url=None, repo_url=RepoUrl('https://huggingface.co/talzoomanzoo/deepseek-1.5b-lowest-spikes-falls-ds-1.5b-fft', endpoint='https://huggingface.co', repo_type='model', repo_id='talzoomanzoo/deepseek-1.5b-lowest-spikes-falls-ds-1.5b-fft'), pr_revision=None, pr_num=None)

# %%
from huggingface_hub import create_repo, upload_folder

repo_id = "talzoomanzoo/deepseek-1.5b-lowest-uid-variance-ds-1.5b-fft"
local_model_path = "/workspace/uid-reasoning/OpenRLHF/mj_scripts/checkpoint/deepseek-1.5b-lowest-uid-variance-ds-1.5b-fft"

create_repo(repo_id, exist_ok=True)

upload_folder(
    repo_id=repo_id,
    folder_path=local_model_path,
    repo_type="model",
    commit_message="deepseek-1.5b-lowest-uid-variance-ds-1.5b-fft"
)
# Out:
# Processing Files (2 / 2): 100%|██████████| 3.57GB / 3.57GB, 87.3MB/s
# New Data Upload: 100%|██████████| 3.35GB / 3.35GB, 87.3MB/s
# CommitInfo(commit_url='https://huggingface.co/talzoomanzoo/deepseek-1.5b-lowest-uid-variance-ds-1.5b-fft/commit/6b441207c182bd5ff5e20f9e52a8ee91bd3b058d', commit_message='deepseek-1.5b-lowest-uid-variance-ds-1.5b-fft', commit_description='', oid='6b441207c182bd5ff5e20f9e52a8ee91bd3b058d', pr_url=None, repo_url=RepoUrl('https://huggingface.co/talzoomanzoo/deepseek-1.5b-lowest-uid-variance-ds-1.5b-fft', endpoint='https://huggingface.co', repo_type='model', repo_id='talzoomanzoo/deepseek-1.5b-lowest-uid-variance-ds-1.5b-fft'), pr_revision=None, pr_num=None)

# %%
from huggingface_hub import create_repo, upload_folder

repo_id = "talzoomanzoo/qwen3-0.6b-highest-spikes-falls-fft"
local_model_path = "/workspace/uid-reasoning/OpenRLHF/mj_scripts/checkpoint/qwen3-0.6b-highest-spikes-falls-fft"

create_repo(repo_id, exist_ok=True)

upload_folder(
    repo_id=repo_id,
    folder_path=local_model_path,
    repo_type="model",
    commit_message="qwen3-0.6b-highest-spikes-falls-fft"
)
# Out:
# Processing Files (1 / 2):  97%|█████████▋| 1.47GB / 1.51GB,  101MB/s
# New Data Upload: 100%|██████████| 1.19GB / 1.19GB, 92.6MB/s
# CommitInfo(commit_url='https://huggingface.co/talzoomanzoo/qwen3-0.6b-highest-spikes-falls-fft/commit/8c212b5660ca6ffd09b2a1d5903ff4293802a646', commit_message='qwen3-0.6b-highest-spikes-falls-fft', commit_description='', oid='8c212b5660ca6ffd09b2a1d5903ff4293802a646', pr_url=None, repo_url=RepoUrl('https://huggingface.co/talzoomanzoo/qwen3-0.6b-highest-spikes-falls-fft', endpoint='https://huggingface.co', repo_type='model', repo_id='talzoomanzoo/qwen3-0.6b-highest-spikes-falls-fft'), pr_revision=None, pr_num=None)

# %%
from huggingface_hub import create_repo, upload_folder

repo_id = "talzoomanzoo/qwen3-0.6b-highest-uid-variance-fft"
local_model_path = "/workspace/uid-reasoning/OpenRLHF/mj_scripts/checkpoint/qwen3-0.6b-highest-uid-variance-fft"

create_repo(repo_id, exist_ok=True)

upload_folder(
    repo_id=repo_id,
    folder_path=local_model_path,
    repo_type="model",
    commit_message="qwen3-0.6b-highest-uid-variance-fft"
)
# Out:
# Processing Files (1 / 2):  97%|█████████▋| 1.47GB / 1.51GB, 93.4MB/s
# New Data Upload: 100%|██████████| 1.19GB / 1.19GB, 92.2MB/s
# CommitInfo(commit_url='https://huggingface.co/talzoomanzoo/qwen3-0.6b-highest-uid-variance-fft/commit/c8adea3b6d42ad7c28e55c29cc42de273741519d', commit_message='qwen3-0.6b-highest-uid-variance-fft', commit_description='', oid='c8adea3b6d42ad7c28e55c29cc42de273741519d', pr_url=None, repo_url=RepoUrl('https://huggingface.co/talzoomanzoo/qwen3-0.6b-highest-uid-variance-fft', endpoint='https://huggingface.co', repo_type='model', repo_id='talzoomanzoo/qwen3-0.6b-highest-uid-variance-fft'), pr_revision=None, pr_num=None)

# %%
from huggingface_hub import create_repo, upload_folder

repo_id = "talzoomanzoo/qwen3-0.6b-lowest-spikes-falls-fft"
local_model_path = "/workspace/uid-reasoning/OpenRLHF/mj_scripts/checkpoint/qwen3-0.6b-lowest-spikes-falls-fft"

create_repo(repo_id, exist_ok=True)

upload_folder(
    repo_id=repo_id,
    folder_path=local_model_path,
    repo_type="model",
    commit_message="qwen3-0.6b-lowest-spikes-falls-fft"
)
# Out:
# Processing Files (1 / 2):  97%|█████████▋| 1.47GB / 1.51GB, 97.7MB/s
# New Data Upload: 100%|██████████| 1.19GB / 1.19GB, 95.0MB/s
# CommitInfo(commit_url='https://huggingface.co/talzoomanzoo/qwen3-0.6b-lowest-spikes-falls-fft/commit/7d3daf55ac615161e3cf2f72a9f9ea6d6686f6d7', commit_message='qwen3-0.6b-lowest-spikes-falls-fft', commit_description='', oid='7d3daf55ac615161e3cf2f72a9f9ea6d6686f6d7', pr_url=None, repo_url=RepoUrl('https://huggingface.co/talzoomanzoo/qwen3-0.6b-lowest-spikes-falls-fft', endpoint='https://huggingface.co', repo_type='model', repo_id='talzoomanzoo/qwen3-0.6b-lowest-spikes-falls-fft'), pr_revision=None, pr_num=None)

# %%
from huggingface_hub import create_repo, upload_folder

repo_id = "talzoomanzoo/qwen3-0.6b-lowest-uid-variance-fft"
local_model_path = "/workspace/uid-reasoning/OpenRLHF/mj_scripts/checkpoint/qwen3-0.6b-lowest-uid-variance-fft"

create_repo(repo_id, exist_ok=True)

upload_folder(
    repo_id=repo_id,
    folder_path=local_model_path,
    repo_type="model",
    commit_message="qwen3-0.6b-lowest-uid-variance-fft"
)
# Out:
# Processing Files (1 / 2):  97%|█████████▋| 1.47GB / 1.51GB,  103MB/s
# New Data Upload: 100%|██████████| 1.19GB / 1.19GB, 92.5MB/s
# CommitInfo(commit_url='https://huggingface.co/talzoomanzoo/qwen3-0.6b-lowest-uid-variance-fft/commit/5904b6b27f95072f27987777418e8c6d6036c470', commit_message='qwen3-0.6b-lowest-uid-variance-fft', commit_description='', oid='5904b6b27f95072f27987777418e8c6d6036c470', pr_url=None, repo_url=RepoUrl('https://huggingface.co/talzoomanzoo/qwen3-0.6b-lowest-uid-variance-fft', endpoint='https://huggingface.co', repo_type='model', repo_id='talzoomanzoo/qwen3-0.6b-lowest-uid-variance-fft'), pr_revision=None, pr_num=None)
