# %% [markdown]
# ### variance

# %%
from huggingface_hub import create_repo, upload_folder

repo_id = "talzoomanzoo/deepseek-1.5b-highest-uid-variance-fft"
local_model_path = "/workspace/uid-reasoning/OpenRLHF/mj_scripts/checkpoint/deepseek-1.5b-highest-uid-variance-ds-1.5b-fft"

create_repo(repo_id, exist_ok=True)

upload_folder(
    repo_id=repo_id,
    folder_path=local_model_path,
    repo_type="model",
    commit_message="deepseek-1.5b-highest-uid-variance-fft"
)
# Out:
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/3.55G [00:00<?, ?B/s]
# Upload 2 LFS files:   0%|          | 0/2 [00:00<?, ?it/s]
# CommitInfo(commit_url='https://huggingface.co/talzoomanzoo/deepseek-1.5b-highest-uid-variance-fft/commit/86882c13b6a2d92f7f2674b30e1736ba79e670fe', commit_message='deepseek-1.5b-highest-uid-variance-fft', commit_description='', oid='86882c13b6a2d92f7f2674b30e1736ba79e670fe', pr_url=None, repo_url=RepoUrl('https://huggingface.co/talzoomanzoo/deepseek-1.5b-highest-uid-variance-fft', endpoint='https://huggingface.co', repo_type='model', repo_id='talzoomanzoo/deepseek-1.5b-highest-uid-variance-fft'), pr_revision=None, pr_num=None)

# %%
from huggingface_hub import create_repo, upload_folder

repo_id = "talzoomanzoo/deepseek-1.5b-lowest-uid-variance-fft"
local_model_path = "/workspace/uid-reasoning/OpenRLHF/mj_scripts/checkpoint/deepseek-1.5b-lowest-uid-variance-ds-1.5b-fft"

create_repo(repo_id, exist_ok=True)

upload_folder(
    repo_id=repo_id,
    folder_path=local_model_path,
    repo_type="model",
    commit_message="deepseek-1.5b-lowest-uid-variance-fft"
)
# Out:
# model.safetensors:   0%|          | 0.00/3.55G [00:00<?, ?B/s]
# Upload 2 LFS files:   0%|          | 0/2 [00:00<?, ?it/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/talzoomanzoo/deepseek-1.5b-lowest-uid-variance-fft/commit/b888e98ae2813ba3d8f7b947e4f247a3e576eb85', commit_message='deepseek-1.5b-lowest-uid-variance-fft', commit_description='', oid='b888e98ae2813ba3d8f7b947e4f247a3e576eb85', pr_url=None, repo_url=RepoUrl('https://huggingface.co/talzoomanzoo/deepseek-1.5b-lowest-uid-variance-fft', endpoint='https://huggingface.co', repo_type='model', repo_id='talzoomanzoo/deepseek-1.5b-lowest-uid-variance-fft'), pr_revision=None, pr_num=None)

# %% [markdown]
# ### gini

# %%
from huggingface_hub import create_repo, upload_folder

repo_id = "talzoomanzoo/deepseek-1.5b-highest-uid-gini-fft"
local_model_path = "/workspace/uid-reasoning/OpenRLHF/mj_scripts/checkpoint/deepseek-1.5b-highest-uid-gini-ds-1.5b-fft"

create_repo(repo_id, exist_ok=True)

upload_folder(
    repo_id=repo_id,
    folder_path=local_model_path,
    repo_type="model",
    commit_message="deepseek-1.5b-highest-uid-gini-fft"
)
# Out:
# Upload 2 LFS files:   0%|          | 0/2 [00:00<?, ?it/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/3.55G [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/talzoomanzoo/deepseek-1.5b-highest-uid-gini-fft/commit/0ba8ec5a7e8f9a3e1134ec9e95bbfb55bb78d7ee', commit_message='deepseek-1.5b-highest-uid-gini-fft', commit_description='', oid='0ba8ec5a7e8f9a3e1134ec9e95bbfb55bb78d7ee', pr_url=None, repo_url=RepoUrl('https://huggingface.co/talzoomanzoo/deepseek-1.5b-highest-uid-gini-fft', endpoint='https://huggingface.co', repo_type='model', repo_id='talzoomanzoo/deepseek-1.5b-highest-uid-gini-fft'), pr_revision=None, pr_num=None)

# %%
from huggingface_hub import create_repo, upload_folder

repo_id = "talzoomanzoo/deepseek-1.5b-lowest-uid-gini-fft"
local_model_path = "/workspace/uid-reasoning/OpenRLHF/mj_scripts/checkpoint/deepseek-1.5b-lowest-uid-gini-ds-1.5b-fft"

create_repo(repo_id, exist_ok=True)

upload_folder(
    repo_id=repo_id,
    folder_path=local_model_path,
    repo_type="model",
    commit_message="deepseek-1.5b-lowest-uid-gini-fft"
)
# Out:
# model.safetensors:   0%|          | 0.00/3.55G [00:00<?, ?B/s]
# Upload 2 LFS files:   0%|          | 0/2 [00:00<?, ?it/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/talzoomanzoo/deepseek-1.5b-lowest-uid-gini-fft/commit/4b3a4bba366ec9c685959b97ca747edb55c9fee0', commit_message='deepseek-1.5b-lowest-uid-gini-fft', commit_description='', oid='4b3a4bba366ec9c685959b97ca747edb55c9fee0', pr_url=None, repo_url=RepoUrl('https://huggingface.co/talzoomanzoo/deepseek-1.5b-lowest-uid-gini-fft', endpoint='https://huggingface.co', repo_type='model', repo_id='talzoomanzoo/deepseek-1.5b-lowest-uid-gini-fft'), pr_revision=None, pr_num=None)

# %% [markdown]
# ### shannon

# %%
from huggingface_hub import create_repo, upload_folder

repo_id = "talzoomanzoo/deepseek-1.5b-highest-uid-shannon-fft"
local_model_path = "/workspace/uid-reasoning/OpenRLHF/mj_scripts/checkpoint/deepseek-1.5b-highest-uid-shannon-ds-1.5b-fft"

create_repo(repo_id, exist_ok=True)

upload_folder(
    repo_id=repo_id,
    folder_path=local_model_path,
    repo_type="model",
    commit_message="deepseek-1.5b-highest-uid-shannon-fft"
)
# Out:
# Upload 2 LFS files:   0%|          | 0/2 [00:00<?, ?it/s]
# model.safetensors:   0%|          | 0.00/3.55G [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/talzoomanzoo/deepseek-1.5b-highest-uid-shannon-fft/commit/921a41a11831e990421e54799968d879a75c26ea', commit_message='deepseek-1.5b-highest-uid-shannon-fft', commit_description='', oid='921a41a11831e990421e54799968d879a75c26ea', pr_url=None, repo_url=RepoUrl('https://huggingface.co/talzoomanzoo/deepseek-1.5b-highest-uid-shannon-fft', endpoint='https://huggingface.co', repo_type='model', repo_id='talzoomanzoo/deepseek-1.5b-highest-uid-shannon-fft'), pr_revision=None, pr_num=None)

# %%
from huggingface_hub import create_repo, upload_folder

repo_id = "talzoomanzoo/deepseek-1.5b-lowest-uid-shannon-fft"
local_model_path = "/workspace/uid-reasoning/OpenRLHF/mj_scripts/checkpoint/deepseek-1.5b-lowest-uid-shannon-ds-1.5b-fft"

create_repo(repo_id, exist_ok=True)

upload_folder(
    repo_id=repo_id,
    folder_path=local_model_path,
    repo_type="model",
    commit_message="deepseek-1.5b-lowest-uid-shannon-fft"
)
# Out:
# model.safetensors:   0%|          | 0.00/3.55G [00:00<?, ?B/s]
# Upload 2 LFS files:   0%|          | 0/2 [00:00<?, ?it/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/talzoomanzoo/deepseek-1.5b-lowest-uid-shannon-fft/commit/f80791b26edba1e6d59e5e72cd6e6e290eb8227e', commit_message='deepseek-1.5b-lowest-uid-shannon-fft', commit_description='', oid='f80791b26edba1e6d59e5e72cd6e6e290eb8227e', pr_url=None, repo_url=RepoUrl('https://huggingface.co/talzoomanzoo/deepseek-1.5b-lowest-uid-shannon-fft', endpoint='https://huggingface.co', repo_type='model', repo_id='talzoomanzoo/deepseek-1.5b-lowest-uid-shannon-fft'), pr_revision=None, pr_num=None)
