# %% [markdown]
# ## RQ1. Which operationalizations of the UID(z) metric correlate with reasoning quality?

# %% [markdown]
# ### Hypothesis 1a: Different UID formulations will capture different aspects of uniformity

# %% [markdown]
# ### Hypothesis 1b: At least one UID operationalization will positively correlate with reasoning quality

# %% [markdown]
# ## RQ2. Which components of the ID_i metric correlate with reasoning quality?

# %% [markdown]
# ### Hypothesis: The composite ID_i explains more variance in reasoning quality than any single component alone
