# %%
import json
with open('/home/hojinkim/mjgwak/search-o1-dev/scripts/outputs/aime.ds-qwen-7b.direct.step-1.test/train.5.1,0:58-10.json', 'r') as f:
    data = json.load(f)

# %%
len(data)
# Out:
# 200
